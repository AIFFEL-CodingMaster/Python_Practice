# %%
import os 
import pandas as pd

# %%
# !python youtube_comments_crawler.py \
--chromedriver=./chromedriver \
--save_name=test.csv \
--url="https://www.youtube.com/watch?v=AwxQ_TsW_II" \
--time_setting=5 \
--down_to_bottom=true

# %%
os.listdir("./comments")
# Out:
# ['test.csv']

# %%
data = pd.read_csv("./comments/test.csv")

# %%
data.iloc[:30,1:]
# Out:
#                                                   cmt like_num
# 0   1기 졸업생 옥수수(그마600)\n2기 만년재수생 고수달(다이아1 어?)\n3기 수...     351개
# 1                           3:35 질투하는 고수달 5:33 우는 고수달     129개
# 2   0:20 Dr.밥도\n3:10 밥멘\n4:36 19살 애송이 상대로 쩔쩔매는 밥\n...      81개
# 3         이젠 진짜 다이아 아이돌 됐네...\n중국아이디도 강찬밥 사랑해를 할줄 알다니      45개
# 4               하루하루 지날때마다 더욱더 질척해지는 다이아 아이돌 밥뻐기.....     144개
# 5        고구마유치, 강친밥, 강찬밥, 고수달, 강고수 ㅋㅋㅋ 엠비션 조력자로 완벽하다.      35개
# 6              '고'수달 죽지도 않었는데 벌써 '고'의 의지를 잇는 사람이 나타났어      68개
# 7                                  07:43 이장면 개웃김ㅋㅋㅋㅋㅋ      36개
# 8   밥집자 ㄹㅇ 진성 트수야ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n소스활용 미쳐버...      13개
# 9                          이 유튜브는 사실상\n고수달과 밥집자의 유튜브다      12개
# 10                      이러다 한 10년 뒤면 플레티넘 아이돌 되겠는걸...       4개
# 11                             우리 수달...버리지마세요..착한아이에요     130개
# 12              우리 수달이 영원히 사랑해줘 그 똘망한 수달 이미지 볼 때마다 설레      94개
# 13  그는 도지코인이다.\n올라갈 것 같아하면서도 떨어진다\n다시 올라선다 하더라도 떨어...       2개
# ...

# %%
# chromedriver
# many_video
# save_name
# url
# time_setting
# video_nums
# scrolldown_nums
# down_to_bottom
