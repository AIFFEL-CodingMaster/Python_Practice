# %%
# !python3 main.py \
--mode="train" \
--data_path="../images/"\
--tfr_path="./pet_data.tfr"\
--img_size=224 \
--model_name="e0" \
--add_layer=dense,batch,dense \
--dense_nums=1024,37\
--dense_activation=relu,n\
--optimizer=adam \
--lr=0.001 \
--loss=sc \
--model_save_path='./model.h5'\
--batch_size=64 \
--epoch=1000 \
--patience=10 \
--lr_schedule=false \
--train_size_rate=0.8
# Out:
# 2021-03-12 19:05:54.798359: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-12 19:05:54.798708: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-12 19:05:54.901634: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Epoch 1/1000
# ^C
# Traceback (most recent call last):
#   File "main.py", line 135, in <module>
#     callbacks=[early_stopping, model_save]
#   File "/opt/anaconda3/envs/cv_env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
# ...
